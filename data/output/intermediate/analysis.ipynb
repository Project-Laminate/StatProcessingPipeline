# %%
# load the csv new_normative_df_output.csv

import pandas as pd

# load the csv file
df = pd.read_csv('new_normative_df_output.csv')

# print the distribution of the last 12 columns of the dataframe 
print(df.iloc[:, -18:].describe())
# Out:
#           frontal_rh    frontal_lh   parietal_rh   parietal_lh  occipital_rh  \
# count     725.000000    725.000000    725.000000    725.000000    725.000000
# mean    75974.704917  75359.622926  50174.842668  48405.046068  22859.387324
# std      7934.192854   7852.900361   5758.264100   5592.644234   3171.674781
# min     56500.592000  54663.528000  30777.512000  29427.261000  13980.815000
# 25%     70284.379000  69933.488000  46252.143000  44470.089000  20683.999000
# 50%     75707.103000  74967.251000  49926.128000  48083.055000  22692.767000
# 75%     81069.253000  80537.501000  53701.569000  51746.121000  25023.685000
# max    101248.822000  98728.663000  69221.022000  66652.069000  36120.775000
#
#        occipital_lh   temporal_rh   temporal_lh  cingulatefrontal_rh  \
# count    725.000000    725.000000    725.000000           725.000000
# mean   22801.344850  47920.375323  48943.934760          4089.362509
# std     3168.083495   5158.699352   5330.251303           732.865237
# min    13460.926000  30320.622000  30448.087000          2283.084000
# 25%    20597.861000  44487.795000  45505.469000          3550.973000
# 50%    22627.794000  47685.388000  48317.287000          4042.333000
# 75%    24884.888000  51396.967000  52477.465000          4564.373000
# max    35978.801000  63454.959000  65255.976000          7016.799000
#
#        cingulatefrontal_lh  cingulateparietal_rh  cingulateparietal_lh  \
# count           725.000000            725.000000            725.000000
# mean           5808.838480           5036.615513           5203.696366
# std             940.367183            690.972357            697.881848
# min            3494.063000           2865.322000           3090.464000
# 25%            5180.334000           4553.829000           4709.863000
# 50%            5702.095000           4995.111000           5132.774000
# 75%            6420.050000           5473.925000           5656.793000
# max            9643.190000           7668.486000           7479.818000
#
#        entorhinalcortex_rh  entorhinalcortex_lh  hippocampus_lh  \
# count           725.000000           725.000000      725.000000
# mean           1653.363182          1712.258902     4040.969763
# std             256.260611           242.961591      453.382835
# min             662.375000           960.476000     2474.511000
# 25%            1495.785000          1551.151000     3730.551000
# 50%            1635.698000          1694.818000     4060.604000
# 75%            1811.821000          1860.189000     4339.713000
# max            2835.484000          2729.631000     5264.443000
#
#        hippocampus_rh  hippocampalpercentage_lh  hippocampalpercentage_rh
# count      725.000000                725.000000                725.000000
# mean      4125.166986                 88.540669                 88.774313
# std        473.330649                  6.800456                  6.653784
# min       2512.679000                 52.589348                 49.759862
# 25%       3826.094000                 86.554462                 86.890240
# 50%       4121.101000                 90.657504                 90.678188
# 75%       4450.850000                 93.132279                 92.919383
# max       5405.226000                 97.246541                 98.042534

# %%
# plot the distribution of the last 18 columns of the dataframe
df.iloc[:, -18:].hist(bins=50, figsize=(20, 15))
# Out:
# array([[<AxesSubplot: title={'center': 'frontal_rh'}>,
#         <AxesSubplot: title={'center': 'frontal_lh'}>,
#         <AxesSubplot: title={'center': 'parietal_rh'}>,
#         <AxesSubplot: title={'center': 'parietal_lh'}>],
#        [<AxesSubplot: title={'center': 'occipital_rh'}>,
#         <AxesSubplot: title={'center': 'occipital_lh'}>,
#         <AxesSubplot: title={'center': 'temporal_rh'}>,
#         <AxesSubplot: title={'center': 'temporal_lh'}>],
#        [<AxesSubplot: title={'center': 'cingulatefrontal_rh'}>,
#         <AxesSubplot: title={'center': 'cingulatefrontal_lh'}>,
#         <AxesSubplot: title={'center': 'cingulateparietal_rh'}>,
#         <AxesSubplot: title={'center': 'cingulateparietal_lh'}>],
#        [<AxesSubplot: title={'center': 'entorhinalcortex_rh'}>,
#         <AxesSubplot: title={'center': 'entorhinalcortex_lh'}>,
#         <AxesSubplot: title={'center': 'hippocampus_lh'}>,
#         <AxesSubplot: title={'center': 'hippocampus_rh'}>],
#        [<AxesSubplot: title={'center': 'hippocampalpercentage_lh'}>,
#         <AxesSubplot: title={'center': 'hippocampalpercentage_rh'}>,
#         <AxesSubplot: >, <AxesSubplot: >]], dtype=object)

# %%
# filter the data based on sex = F and age = +- 64 


# Calculating age range for filtering
age_range_min = 64*12 - 60  # Subtracting 5 years in months
age_range_max = 64*12 + 60  # Adding 5 years in months

# Filtering normative_df based on sex and age range
filtered_normative_df = df[
    (df["sex"] == 'F')
    & (df["age"] >= age_range_min)
    & (df["age"] <= age_range_max)
]
